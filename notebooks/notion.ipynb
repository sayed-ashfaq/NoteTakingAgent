# %%
print("Hello")
# Out:
# Hello

# %%
import os
from dotenv import load_dotenv
load_dotenv()

NOTION_TOKEN = os.getenv("NOTION_API_KEY")
DATABASE_ID = os.getenv("NOTION_API_KEY")

# %%
import datetime
now = datetime.datetime.now()

# %%
now
# Out:
# datetime.datetime(2026, 2, 16, 21, 57, 41, 14157)
